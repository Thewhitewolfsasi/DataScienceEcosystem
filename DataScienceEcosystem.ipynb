# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem
# ![2-title.png](attachment:02296074-3afa-4b32-b727-89a4e5c2bbb8.jpg)

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystem are summarized.
#
# Jupyter Notebook is browser based application that allows you to create and share documents. It allows to record the data science experiments. It combine the texts, code block, generate plots and tables within the line. It can be exported as PDF and HTML files.
# ![3-intro.png](attachment:61fbe375-c373-4f6c-bed3-94f051e02464.png)

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science
# - Common Libraries used by Data Scientists
# - Three Development environment open source Data science tool
# - Arithmetic expression examples
# - Program for convert minutes to hours
# ![10-objectives.png](attachment:d92a0b45-ea6e-4f3c-ac77-e00f2c26540c.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1) Python - High level programming language and it has many computing libraries and functions that is used to conduct analysis, deploy the machine learning models into data.
#
# 2) R - Statistical Programming Language used for data processing and manipulation.
#
# 3) SQL- SQL stands for Structured Query Language which is designed for querying and managing data in relational databases and acts as interpreter between user and databases
#
# Some of the other languages that used for data science are Scala, Java, C++, Julia, JS, PHP, Go, Ruby, Visual Basic etc.,
# ![4-dslanguages.png](attachment:7347126b-0afa-41a6-9b29-f17b2c7cfde1.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# 1) Python
# - Scientific Computing Libraries - Pandas, Numpy, SciPy
# - Visualization libraries - Matplotlib, Seaborn
# - Machine learning libraries - Scikit learn, Keras
# - Deep Learning libraries - Tensorflow, Pytorch, Caffe2
#
# 2) R
# - Data manipulation - dplyr
# - String manipulation - stringr
# - Data visualization - ggplot, plotly, lattice
# - Machine learning - caret
# - Interactive plots - Leaflet
# - Time series analysis - tseries
#
# 3) Scala
# - Computing libraries - Apache spark, Apache shark
# - Machine learning - MLib
#
# 4) C++
# - Database - MongoDB
# - Deep learning - Caffe, Tensorflow
#
# 5) Julia
# - Database - JuliaDB
#
# ![5-dslibraries.png](attachment:76cd17a9-0859-4074-bbb2-40b51dc7b6b4.png)

# %% [markdown]
# **Data Science Tools** |
# -----------------------|
# JupyterLab & Notebook  |
# Zeppelin               |
# R Studio               |
# ![6-dstools.png](attachment:aa252685-ff6c-4a62-aeae-96bde8d5f172.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.
# ![7-introarithmetic.png](attachment:20fefcc2-8817-4091-8673-4616a4064070.png)

# %%
#This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:76aaefc7-3e4d-4ec2-a0b1-a1d39af67c23.png)

# %%
#This will convert 200 minutes to hours by diving by 60
min = 200
hours = min / 60
print(hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.png](attachment:74d28f87-e5f5-49cf-a9bb-21cc8e669e07.png)

# %% [markdown]
# ## Author
# Sasidharan Vairavasamy
# ![11-authordetails.png](attachment:5055fb45-6f0f-4e46-b4f6-2780817fa3ee.png)
